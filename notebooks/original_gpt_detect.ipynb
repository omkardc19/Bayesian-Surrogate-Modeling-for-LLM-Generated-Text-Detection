# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
# !pip install hf_xet
# Out:
# Collecting hf_xet
#   Downloading hf_xet-1.1.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (494 bytes)
# Downloading hf_xet-1.1.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 MB 31.5 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: hf_xet
# Successfully installed hf_xet-1.1.0

# %%
import os

path = os.listdir('/kaggle/input')[0]
print("Input path:", path)
# Out:
# Input path: llm-human-classification-data

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
import pandas as pd

from tqdm import tqdm
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformers import T5ForConditionalGeneration, T5Tokenizer
from typing import List

# %%
def print_gpu_memory():
    if torch.cuda.is_available():
        print(f"GPU Name: {torch.cuda.get_device_name(0)}")
        print(f"Total memory: {torch.cuda.get_device_properties(0).total_memory / 1024 ** 2:.2f} MB")
        print(f"Allocated memory: {torch.cuda.memory_allocated(0) / 1024 ** 2:.2f} MB")
        print(f"Reserved memory: {torch.cuda.memory_reserved(0) / 1024 ** 2:.2f} MB")
        print(f"Free (unreserved) memory: {(torch.cuda.memory_reserved(0) - torch.cuda.memory_allocated(0)) / 1024 ** 2:.2f} MB")
    else:
        print("CUDA not available.")

print_gpu_memory()
# Out:
# GPU Name: Tesla P100-PCIE-16GB
# Total memory: 16269.25 MB
# Allocated memory: 0.00 MB
# Reserved memory: 0.00 MB
# Free (unreserved) memory: 0.00 MB

# %%
dataset = pd.read_csv('/kaggle/input/llm-human-classification-data/LLM-Human Classification Data.csv')
dataset.shape
# Out:
# (29145, 2)

# %%
llm_dataset = dataset[dataset['generated'] == 1]
human_dataset = dataset[dataset['generated'] == 0]
print(llm_dataset.shape, human_dataset.shape)

llm_dataset = llm_dataset[:int((llm_dataset.shape[0])*0.05)]
human_dataset = human_dataset[:int((human_dataset.shape[0])*0.03)]
print(llm_dataset.shape, human_dataset.shape)

smaller_dataset = pd.concat([llm_dataset, human_dataset])
smaller_dataset = smaller_dataset.sample(frac=1)
smaller_dataset.shape
# Out:
# (11637, 2) (17508, 2)
# (581, 2) (525, 2)
# (1106, 2)

# %%
print(smaller_dataset['generated'].value_counts())
# Out:
# generated
# 1    581
# 0    525
# Name: count, dtype: int64

# %%
smaller_dataset.head()
# Out:
#                                                   text  generated
# 182  Limiting car usage can have several advantages...          1
# 751  "America's love affair with it's vehicles seem...          0
# 801  Reducing the usage of cars in today's world co...          0
# 385  [Your Name]\n[Your Address]\n[City, State, ZIP...          1
# 495  [Your Name]\n[Your Address]\n[City, State, ZIP...          1

# %%
class PerturbationGenerator:
    def __init__(self, model_name: str = "t5-small"):
        self.tokenizer = T5Tokenizer.from_pretrained(model_name)
        self.model = T5ForConditionalGeneration.from_pretrained(model_name)
        self.tokenizer.model_max_length = 512
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model.to(self.device)

    def perturb(self, text: str, num_samples: int = 9) -> List[str]:
        inputs = self.tokenizer(
            f"paraphrase: {text}", return_tensors="pt", max_length=512, truncation=True
        ).to(self.device)

        outputs = self.model.generate(
            input_ids=inputs.input_ids,
            attention_mask=inputs.attention_mask,
            num_return_sequences=num_samples,
            do_sample=True,
            max_length=512,
        )
        
        return [self.tokenizer.decode(out, skip_special_tokens=True) for out in outputs]

# %%
class SourceModel:
    def __init__(self, model_name="gpt2"):
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16)
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model.to(self.device)
        self.model.eval()

        
    def get_log_prob(self, texts: List[str]) -> torch.Tensor:
        log_probs = []
        with torch.no_grad():
            for text in texts:
                inputs = self.tokenizer(text, return_tensors="pt", truncation=True).to(self.device)
                
                # Handle empty input
                if inputs["input_ids"].shape[1] == 0:
                    log_probs.append(0.0)
                    continue
                
                # Handle single-token edge case
                num_tokens = inputs["input_ids"].shape[1]
                if num_tokens == 1:
                    log_probs.append(0.0)
                    continue
                
                outputs = self.model(**inputs, labels=inputs["input_ids"])
                logits = outputs.logits
                labels = inputs["input_ids"]
                
                log_probs_seq = torch.log_softmax(logits, dim=-1)[:, :-1, :]
                log_probs_text = torch.gather(
                    log_probs_seq, 
                    dim=2, 
                    index=labels[:, 1:, None]
                ).squeeze(-1).sum(dim=1)

                normalized_log_prob = log_probs_text.item() / (num_tokens - 1)  
                log_probs.append(normalized_log_prob)
            
        # print(log_probs)    
        return torch.tensor(log_probs)

# %%
class ScoreCalculator:
    def __init__(self):
        self.perturb_model = PerturbationGenerator(model_name='t5-small')
        self.source_model = SourceModel(model_name='gpt2')

    def score(self, candidate_text):
        perturbations = self.perturb_model.perturb(text=candidate_text, num_samples=200)     #   Increase for better accuracy
        candidate_text_log_prob = self.source_model.get_log_prob([candidate_text])
        perturbations_log_prob = self.source_model.get_log_prob(perturbations)

        detection_score = candidate_text_log_prob - perturbations_log_prob.mean()
        return detection_score

# %%
sc = ScoreCalculator()
sentences = list(smaller_dataset['text'])
pred_scores = []
for num, sentence in enumerate(sentences, 1):
    pred_scores.append(sc.score(candidate_text=sentence).item())
    print(f"Detection Score for sentence {num} is: {pred_scores[num-1]:0.4f}")
    torch.cuda.empty_cache()
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
# Detection Score for sentence 1 is: 1.4925
# Detection Score for sentence 2 is: 0.9193
# Detection Score for sentence 3 is: 0.9531
# Detection Score for sentence 4 is: 0.7727
# Detection Score for sentence 5 is: 1.1324
# Detection Score for sentence 6 is: 1.1604
# Detection Score for sentence 7 is: 0.4272
# Detection Score for sentence 8 is: 1.1788
# Detection Score for sentence 9 is: 0.9612
# Detection Score for sentence 10 is: 0.6684
# Detection Score for sentence 11 is: 1.6174
# Detection Score for sentence 12 is: 0.9444
# Detection Score for sentence 13 is: 1.5346
# Detection Score for sentence 14 is: 1.3359
# Detection Score for sentence 15 is: 0.4728
# Detection Score for sentence 16 is: 0.7908
# Detection Score for sentence 17 is: 0.2086
# Detection Score for sentence 18 is: 0.6544
# Detection Score for sentence 19 is: 0.5293
# Detection Score for sentence 20 is: 0.7288
# Detection Score for sentence 21 is: 0.7866
# Detection Score for sentence 22 is: 0.0996
# Detection Score for sentence 23 is: 1.1404
# Detection Score for sentence 24 is: 0.7883
# Detection Score for sentence 25 is: 0.0822
# Detection Score for sentence 26 is: 1.4951
# Detection Score for sentence 27 is: 0.5007
# Detection Score for sentence 28 is: 1.3363
# Detection Score for sentence 29 is: 0.4880
# Detection Score for sentence 30 is: 1.3588
# Detection Score for sentence 31 is: 0.5914
# Detection Score for sentence 32 is: 0.9397
# Detection Score for sentence 33 is: 1.5565
# Detection Score for sentence 34 is: 0.6551
# Detection Score for sentence 35 is: 1.2607
# Detection Score for sentence 36 is: 1.6911
# Detection Score for sentence 37 is: 0.2932
# Detection Score for sentence 38 is: 1.4553
# Detection Score for sentence 39 is: 0.7099
# Detection Score for sentence 40 is: 0.3788
# Detection Score for sentence 41 is: 0.9133
# Detection Score for sentence 42 is: 0.4894
# Detection Score for sentence 43 is: 0.7330
# Detection Score for sentence 44 is: 0.2348
# Detection Score for sentence 45 is: 0.6849
# Detection Score for sentence 46 is: 0.0800
# Detection Score for sentence 47 is: 1.2099
# Detection Score for sentence 48 is: 1.2947
# Detection Score for sentence 49 is: 1.3067
# Detection Score for sentence 50 is: 1.4800
# Detection Score for sentence 51 is: 0.7311
# Detection Score for sentence 52 is: 0.8014
# Detection Score for sentence 53 is: 1.4254
# Detection Score for sentence 54 is: 1.5272
# Detection Score for sentence 55 is: 0.7388
# Detection Score for sentence 56 is: 1.6393
# Detection Score for sentence 57 is: 1.0416
# Detection Score for sentence 58 is: 1.3159
# Detection Score for sentence 59 is: 0.5372
# Detection Score for sentence 60 is: 0.8516
# Detection Score for sentence 61 is: 1.0714
# Detection Score for sentence 62 is: 0.5045
# Detection Score for sentence 63 is: 1.7825
# Detection Score for sentence 64 is: 1.4333
# Detection Score for sentence 65 is: 0.3761
# Detection Score for sentence 66 is: 1.4379
# Detection Score for sentence 67 is: 0.3094
# Detection Score for sentence 68 is: 0.6772
# Detection Score for sentence 69 is: 1.0219
# Detection Score for sentence 70 is: 1.1355
# Detection Score for sentence 71 is: 1.3968
# Detection Score for sentence 72 is: -0.2322
# Detection Score for sentence 73 is: 0.5268
# Detection Score for sentence 74 is: 1.4563
# Detection Score for sentence 75 is: 0.5748
# Detection Score for sentence 76 is: 0.7677
# Detection Score for sentence 77 is: 1.5735
# Detection Score for sentence 78 is: 0.3600
# Detection Score for sentence 79 is: 0.9921
# Detection Score for sentence 80 is: 0.7351
# Detection Score for sentence 81 is: 0.6388
# Detection Score for sentence 82 is: 1.7688
# Detection Score for sentence 83 is: 0.9998
# Detection Score for sentence 84 is: 0.7837
# Detection Score for sentence 85 is: 1.4720
# Detection Score for sentence 86 is: 1.1249
# Detection Score for sentence 87 is: 1.4147
# Detection Score for sentence 88 is: 0.6224
# Detection Score for sentence 89 is: 0.6053
# Detection Score for sentence 90 is: 0.5208
# Detection Score for sentence 91 is: 1.5812
# Detection Score for sentence 92 is: 1.4753
# Detection Score for sentence 93 is: 0.3636
# Detection Score for sentence 94 is: 1.5257
# Detection Score for sentence 95 is: 0.7553
# Detection Score for sentence 96 is: 1.3613
# Detection Score for sentence 97 is: 0.7298
# Detection Score for sentence 98 is: 0.4290
# Detection Score for sentence 99 is: 0.9544
# Detection Score for sentence 100 is: 0.8738
# Detection Score for sentence 101 is: 0.9739
# Detection Score for sentence 102 is: 0.8336
# Detection Score for sentence 103 is: 1.1136
# Detection Score for sentence 104 is: 0.8603
# Detection Score for sentence 105 is: 1.2700
# Detection Score for sentence 106 is: 1.2328
# Detection Score for sentence 107 is: 1.1173
# Detection Score for sentence 108 is: 1.4218
# Detection Score for sentence 109 is: 0.9178
# Detection Score for sentence 110 is: 1.6203
# Detection Score for sentence 111 is: 1.3959
# Detection Score for sentence 112 is: 0.9641
# Detection Score for sentence 113 is: 0.7625
# Detection Score for sentence 114 is: 1.3386
# Detection Score for sentence 115 is: 1.2748
# Detection Score for sentence 116 is: 0.2436
# Detection Score for sentence 117 is: -2.8910
# Detection Score for sentence 118 is: 0.9268
# Detection Score for sentence 119 is: 0.6572
# Detection Score for sentence 120 is: 0.9415
# Detection Score for sentence 121 is: 0.4679
# Detection Score for sentence 122 is: 1.0925
# Detection Score for sentence 123 is: 1.6227
# Detection Score for sentence 124 is: 0.7558
# Detection Score for sentence 125 is: 1.4787
# Detection Score for sentence 126 is: 0.6911
# Detection Score for sentence 127 is: 0.9140
# Detection Score for sentence 128 is: 0.7641
# Detection Score for sentence 129 is: 0.8319
# Detection Score for sentence 130 is: 0.7865
# Detection Score for sentence 131 is: 0.4171
# Detection Score for sentence 132 is: 0.6649
# Detection Score for sentence 133 is: 0.9019
# Detection Score for sentence 134 is: 1.4113
# Detection Score for sentence 135 is: 0.9498
# Detection Score for sentence 136 is: 0.9779
# Detection Score for sentence 137 is: 0.9383
# Detection Score for sentence 138 is: 0.9268
# Detection Score for sentence 139 is: 1.4810
# Detection Score for sentence 140 is: 1.0974
# Detection Score for sentence 141 is: 0.4590
# Detection Score for sentence 142 is: 1.3100
# Detection Score for sentence 143 is: 0.6363
# Detection Score for sentence 144 is: 0.8423
# Detection Score for sentence 145 is: 1.5056
# Detection Score for sentence 146 is: 0.8925
# Detection Score for sentence 147 is: 1.1381
# Detection Score for sentence 148 is: 0.1425
# Detection Score for sentence 149 is: 0.8704
# Detection Score for sentence 150 is: 1.0003
# Detection Score for sentence 151 is: 0.3172
# Detection Score for sentence 152 is: 1.4870
# Detection Score for sentence 153 is: 1.2199
# Detection Score for sentence 154 is: 0.3847
# Detection Score for sentence 155 is: 0.8039
# Detection Score for sentence 156 is: 1.0360
# Detection Score for sentence 157 is: 0.9944
# Detection Score for sentence 158 is: 0.6808
# Detection Score for sentence 159 is: 1.2540
# Detection Score for sentence 160 is: 1.1924
# Detection Score for sentence 161 is: 0.7229
# Detection Score for sentence 162 is: 1.3490
# Detection Score for sentence 163 is: 1.2047
# Detection Score for sentence 164 is: 0.7736
# Detection Score for sentence 165 is: 1.0751
# Detection Score for sentence 166 is: 1.2759
# Detection Score for sentence 167 is: 0.1343
# Detection Score for sentence 168 is: 1.3245
# Detection Score for sentence 169 is: 0.8299
# Detection Score for sentence 170 is: 1.4187
# Detection Score for sentence 171 is: 1.7043
# Detection Score for sentence 172 is: 0.7866
# Detection Score for sentence 173 is: 1.6270
# Detection Score for sentence 174 is: 1.4066
# Detection Score for sentence 175 is: 1.3271
# Detection Score for sentence 176 is: 0.7102
# Detection Score for sentence 177 is: 0.2800
# Detection Score for sentence 178 is: 0.6443
# Detection Score for sentence 179 is: 1.2486
# Detection Score for sentence 180 is: 0.6387
# Detection Score for sentence 181 is: 0.9578
# Detection Score for sentence 182 is: 1.2492
# Detection Score for sentence 183 is: 0.6501
# Detection Score for sentence 184 is: 0.4890
# Detection Score for sentence 185 is: 1.4659
# Detection Score for sentence 186 is: 0.6314
# Detection Score for sentence 187 is: 0.8640
# Detection Score for sentence 188 is: 1.1895
# Detection Score for sentence 189 is: 0.5398
# Detection Score for sentence 190 is: 0.8116
# Detection Score for sentence 191 is: 1.0908
# Detection Score for sentence 192 is: 0.9310
# Detection Score for sentence 193 is: 1.6071
# Detection Score for sentence 194 is: 0.8047
# Detection Score for sentence 195 is: 0.6603
# Detection Score for sentence 196 is: 1.1796
# Detection Score for sentence 197 is: 1.0176
# Detection Score for sentence 198 is: 0.7711
# Detection Score for sentence 199 is: 0.1670
# Detection Score for sentence 200 is: 0.7431
# Detection Score for sentence 201 is: 0.6567
# Detection Score for sentence 202 is: 0.9496
# Detection Score for sentence 203 is: 0.4828
# Detection Score for sentence 204 is: 1.1529
# Detection Score for sentence 205 is: 0.8016
# Detection Score for sentence 206 is: 0.6964
# Detection Score for sentence 207 is: 1.2744
# Detection Score for sentence 208 is: 0.7526
# Detection Score for sentence 209 is: 1.2102
# Detection Score for sentence 210 is: 0.8086
# Detection Score for sentence 211 is: 1.6325
# Detection Score for sentence 212 is: 1.2124
# Detection Score for sentence 213 is: 1.4623
# Detection Score for sentence 214 is: 0.7659
# Detection Score for sentence 215 is: 0.3860
# Detection Score for sentence 216 is: 0.4418
# Detection Score for sentence 217 is: 0.8099
# Detection Score for sentence 218 is: 1.6238
# Detection Score for sentence 219 is: 0.9774
# Detection Score for sentence 220 is: 1.0184
# Detection Score for sentence 221 is: 1.0516
# Detection Score for sentence 222 is: 0.7373
# Detection Score for sentence 223 is: 0.5927
# Detection Score for sentence 224 is: 0.8405
# Detection Score for sentence 225 is: 1.4403
# Detection Score for sentence 226 is: 0.6541
# Detection Score for sentence 227 is: 1.3961
# Detection Score for sentence 228 is: 0.8190
# Detection Score for sentence 229 is: 1.0971
# Detection Score for sentence 230 is: 0.6079
# Detection Score for sentence 231 is: 0.5317
# Detection Score for sentence 232 is: 1.2349
# Detection Score for sentence 233 is: 0.9977
# Detection Score for sentence 234 is: 0.6151
# Detection Score for sentence 235 is: 1.1807
# Detection Score for sentence 236 is: 1.4012
# Detection Score for sentence 237 is: 0.5668
# Detection Score for sentence 238 is: 1.3228
# Detection Score for sentence 239 is: 1.6020
# Detection Score for sentence 240 is: 1.2222
# Detection Score for sentence 241 is: 0.8326
# Detection Score for sentence 242 is: 1.6230
# Detection Score for sentence 243 is: 0.9257
# Detection Score for sentence 244 is: 0.9286
# Detection Score for sentence 245 is: 0.8761
# Detection Score for sentence 246 is: 1.3320
# Detection Score for sentence 247 is: 0.9154
# Detection Score for sentence 248 is: 0.9924
# Detection Score for sentence 249 is: 0.6964
# Detection Score for sentence 250 is: 0.8964
# Detection Score for sentence 251 is: 1.4817
# Detection Score for sentence 252 is: 1.0092
# Detection Score for sentence 253 is: 0.6526
# Detection Score for sentence 254 is: 0.9517
# Detection Score for sentence 255 is: 0.6485
# Detection Score for sentence 256 is: 0.7290
# Detection Score for sentence 257 is: 0.6655
# Detection Score for sentence 258 is: 1.0214
# Detection Score for sentence 259 is: 1.2660
# Detection Score for sentence 260 is: 0.4145
# Detection Score for sentence 261 is: 0.8386
# Detection Score for sentence 262 is: 0.6196
# Detection Score for sentence 263 is: 1.4387
# Detection Score for sentence 264 is: 0.9805
# Detection Score for sentence 265 is: 1.0528
# Detection Score for sentence 266 is: 0.3706
# Detection Score for sentence 267 is: 1.0457
# Detection Score for sentence 268 is: 1.4609
# Detection Score for sentence 269 is: 1.5460
# Detection Score for sentence 270 is: 0.5590
# Detection Score for sentence 271 is: 0.6943
# Detection Score for sentence 272 is: 1.5062
# Detection Score for sentence 273 is: -0.2168
# Detection Score for sentence 274 is: 0.4707
# Detection Score for sentence 275 is: -2.4047
# Detection Score for sentence 276 is: 0.9499
# Detection Score for sentence 277 is: 0.4109
# Detection Score for sentence 278 is: -0.2616
# Detection Score for sentence 279 is: 0.7874
# Detection Score for sentence 280 is: 1.5375
# Detection Score for sentence 281 is: 0.9299
# Detection Score for sentence 282 is: 0.7142
# Detection Score for sentence 283 is: 0.7463
# Detection Score for sentence 284 is: 0.9224
# Detection Score for sentence 285 is: 1.2379
# Detection Score for sentence 286 is: 0.0845
# Detection Score for sentence 287 is: 1.0669
# Detection Score for sentence 288 is: -3.4613
# Detection Score for sentence 289 is: 1.4626
# Detection Score for sentence 290 is: 1.6437
# Detection Score for sentence 291 is: 0.7984
# Detection Score for sentence 292 is: 0.7377
# Detection Score for sentence 293 is: 0.5706
# Detection Score for sentence 294 is: 1.1330
# Detection Score for sentence 295 is: -0.8451
# Detection Score for sentence 296 is: 1.5419
# Detection Score for sentence 297 is: 0.7961
# Detection Score for sentence 298 is: 1.3768
# Detection Score for sentence 299 is: 0.4917
# Detection Score for sentence 300 is: 1.0606
# Detection Score for sentence 301 is: 1.3765
# Detection Score for sentence 302 is: 1.5016
# Detection Score for sentence 303 is: 0.4695
# Detection Score for sentence 304 is: 1.0001
# Detection Score for sentence 305 is: 0.7260
# Detection Score for sentence 306 is: 1.0395
# Detection Score for sentence 307 is: 0.8922
# Detection Score for sentence 308 is: 0.9924
# Detection Score for sentence 309 is: 0.8075
# Detection Score for sentence 310 is: 0.9646
# Detection Score for sentence 311 is: 0.7272
# Detection Score for sentence 312 is: 0.6182
# Detection Score for sentence 313 is: 0.5627
# Detection Score for sentence 314 is: 1.4077
# Detection Score for sentence 315 is: 0.8701
# Detection Score for sentence 316 is: 0.6808
# Detection Score for sentence 317 is: 0.9732
# Detection Score for sentence 318 is: 1.7738
# Detection Score for sentence 319 is: 0.8288
# Detection Score for sentence 320 is: 1.0021
# Detection Score for sentence 321 is: 0.8637
# Detection Score for sentence 322 is: 0.7769
# Detection Score for sentence 323 is: 0.9138
# Detection Score for sentence 324 is: 0.5066
# Detection Score for sentence 325 is: 0.7851
# Detection Score for sentence 326 is: 1.2161
# Detection Score for sentence 327 is: 1.4673
# Detection Score for sentence 328 is: 0.5086
# Detection Score for sentence 329 is: 1.0000
# Detection Score for sentence 330 is: 0.6340
# Detection Score for sentence 331 is: 1.0999
# Detection Score for sentence 332 is: 0.9074
# Detection Score for sentence 333 is: 1.1012
# Detection Score for sentence 334 is: -0.1495
# Detection Score for sentence 335 is: 0.7458
# Detection Score for sentence 336 is: 0.8990
# Detection Score for sentence 337 is: 1.0684
# Detection Score for sentence 338 is: 0.7409
# Detection Score for sentence 339 is: 0.9376
# Detection Score for sentence 340 is: 1.0493
# Detection Score for sentence 341 is: 1.7688
# Detection Score for sentence 342 is: 0.9830
# Detection Score for sentence 343 is: 0.6971
# Detection Score for sentence 344 is: 1.6151
# Detection Score for sentence 345 is: 0.6319
# Detection Score for sentence 346 is: 0.6205
# Detection Score for sentence 347 is: 1.2195
# Detection Score for sentence 348 is: 0.4338
# Detection Score for sentence 349 is: 1.4750
# Detection Score for sentence 350 is: 0.8507
# Detection Score for sentence 351 is: 1.1377
# Detection Score for sentence 352 is: 0.9067
# Detection Score for sentence 353 is: 0.7018
# Detection Score for sentence 354 is: 1.3022
# Detection Score for sentence 355 is: 0.4614
# Detection Score for sentence 356 is: 0.8577
# Detection Score for sentence 357 is: 0.5304
# Detection Score for sentence 358 is: 1.0524
# Detection Score for sentence 359 is: 0.6629
# Detection Score for sentence 360 is: 1.2066
# Detection Score for sentence 361 is: 1.4902
# Detection Score for sentence 362 is: 1.0552
# Detection Score for sentence 363 is: 0.4417
# Detection Score for sentence 364 is: 0.4356
# Detection Score for sentence 365 is: 0.7917
# Detection Score for sentence 366 is: 0.5233
# Detection Score for sentence 367 is: 0.7893
# Detection Score for sentence 368 is: 0.7006
# Detection Score for sentence 369 is: 1.0294
# Detection Score for sentence 370 is: 0.6855
# Detection Score for sentence 371 is: 0.7917
# Detection Score for sentence 372 is: 1.2136
# Detection Score for sentence 373 is: 0.8280
# Detection Score for sentence 374 is: 1.0674
# Detection Score for sentence 375 is: 1.6433
# Detection Score for sentence 376 is: 1.4224
# Detection Score for sentence 377 is: 0.7708
# Detection Score for sentence 378 is: 1.5306
# Detection Score for sentence 379 is: 1.5763
# Detection Score for sentence 380 is: 0.8125
# Detection Score for sentence 381 is: -0.3224
# Detection Score for sentence 382 is: 0.7219
# Detection Score for sentence 383 is: 0.9104
# Detection Score for sentence 384 is: 0.5341
# Detection Score for sentence 385 is: 0.6641
# Detection Score for sentence 386 is: 1.0396
# Detection Score for sentence 387 is: 0.6875
# Detection Score for sentence 388 is: 1.0142
# Detection Score for sentence 389 is: 0.7804
# Detection Score for sentence 390 is: 0.7172
# Detection Score for sentence 391 is: 1.5039
# Detection Score for sentence 392 is: 1.0282
# Detection Score for sentence 393 is: 0.7406
# Detection Score for sentence 394 is: 1.0949
# Detection Score for sentence 395 is: 1.0307
# Detection Score for sentence 396 is: 1.6596
# Detection Score for sentence 397 is: 1.2603
# Detection Score for sentence 398 is: 0.8836
# Detection Score for sentence 399 is: 1.4365
# Detection Score for sentence 400 is: 0.5307
# Detection Score for sentence 401 is: 1.6393
# Detection Score for sentence 402 is: 0.6016
# Detection Score for sentence 403 is: 1.4427
# Detection Score for sentence 404 is: 1.1076
# Detection Score for sentence 405 is: 0.7169
# Detection Score for sentence 406 is: 1.6133
# Detection Score for sentence 407 is: 1.7787
# Detection Score for sentence 408 is: 0.5895
# Detection Score for sentence 409 is: 1.0341
# Detection Score for sentence 410 is: 1.4480
# Detection Score for sentence 411 is: 0.5213
# Detection Score for sentence 412 is: 1.0586
# Detection Score for sentence 413 is: 0.8404
# Detection Score for sentence 414 is: 1.1754
# Detection Score for sentence 415 is: 0.6044
# Detection Score for sentence 416 is: 1.0716
# Detection Score for sentence 417 is: 1.5394
# Detection Score for sentence 418 is: 0.5866
# Detection Score for sentence 419 is: 0.4567
# Detection Score for sentence 420 is: 0.6189
# Detection Score for sentence 421 is: 1.0895
# Detection Score for sentence 422 is: 0.5764
# Detection Score for sentence 423 is: 1.1045
# Detection Score for sentence 424 is: 0.6619
# Detection Score for sentence 425 is: 0.2234
# Detection Score for sentence 426 is: 0.5929
# Detection Score for sentence 427 is: 0.7770
# Detection Score for sentence 428 is: 0.8317
# Detection Score for sentence 429 is: 0.2802
# Detection Score for sentence 430 is: 1.0224
# Detection Score for sentence 431 is: 1.0231
# Detection Score for sentence 432 is: 0.6478
# Detection Score for sentence 433 is: 0.8588
# Detection Score for sentence 434 is: 1.6052
# Detection Score for sentence 435 is: 1.5811
# Detection Score for sentence 436 is: 0.3001
# Detection Score for sentence 437 is: 0.9791
# Detection Score for sentence 438 is: 0.5974
# Detection Score for sentence 439 is: 0.6774
# Detection Score for sentence 440 is: 0.3602
# Detection Score for sentence 441 is: 0.9083
# Detection Score for sentence 442 is: 0.3768
# Detection Score for sentence 443 is: 0.5038
# Detection Score for sentence 444 is: 1.2307
# Detection Score for sentence 445 is: 1.2626
# Detection Score for sentence 446 is: 1.2530
# Detection Score for sentence 447 is: 0.9629
# Detection Score for sentence 448 is: 1.0541
# Detection Score for sentence 449 is: 0.8998
# Detection Score for sentence 450 is: 0.5629
# Detection Score for sentence 451 is: 0.9928
# Detection Score for sentence 452 is: 1.7496
# Detection Score for sentence 453 is: 1.5398
# Detection Score for sentence 454 is: 0.2066
# Detection Score for sentence 455 is: 0.3848
# Detection Score for sentence 456 is: 1.1149
# Detection Score for sentence 457 is: 0.8368
# Detection Score for sentence 458 is: 1.2932
# Detection Score for sentence 459 is: 0.7669
# Detection Score for sentence 460 is: 1.2593
# Detection Score for sentence 461 is: 1.0571
# Detection Score for sentence 462 is: 0.6923
# Detection Score for sentence 463 is: 0.3220
# Detection Score for sentence 464 is: 1.1711
# Detection Score for sentence 465 is: 0.9719
# Detection Score for sentence 466 is: 0.4674
# Detection Score for sentence 467 is: 1.2460
# Detection Score for sentence 468 is: 1.4766
# Detection Score for sentence 469 is: 0.2958
# Detection Score for sentence 470 is: 1.1143
# Detection Score for sentence 471 is: 1.5316
# Detection Score for sentence 472 is: 0.5267
# Detection Score for sentence 473 is: 0.5737
# Detection Score for sentence 474 is: 1.4326
# Detection Score for sentence 475 is: 1.6404
# Detection Score for sentence 476 is: 1.1668
# Detection Score for sentence 477 is: 0.6943
# Detection Score for sentence 478 is: 1.1032
# Detection Score for sentence 479 is: 0.4396
# Detection Score for sentence 480 is: 0.8943
# Detection Score for sentence 481 is: 1.3116
# Detection Score for sentence 482 is: 0.8783
# Detection Score for sentence 483 is: 0.5495
# Detection Score for sentence 484 is: 0.8355
# Detection Score for sentence 485 is: 0.6131
# Detection Score for sentence 486 is: 0.7958
# Detection Score for sentence 487 is: 1.0494
# Detection Score for sentence 488 is: 0.6700
# Detection Score for sentence 489 is: 0.9643
# Detection Score for sentence 490 is: -2.0000
# Detection Score for sentence 491 is: 0.7224
# Detection Score for sentence 492 is: 1.3439
# Detection Score for sentence 493 is: 1.1183
# Detection Score for sentence 494 is: 0.6821
# Detection Score for sentence 495 is: 1.1069
# Detection Score for sentence 496 is: 0.5171
# Detection Score for sentence 497 is: 0.5431
# Detection Score for sentence 498 is: -0.5055
# Detection Score for sentence 499 is: 0.4217
# Detection Score for sentence 500 is: 0.3674
# Detection Score for sentence 501 is: 0.8825
# Detection Score for sentence 502 is: 1.5393
# Detection Score for sentence 503 is: 1.2644
# Detection Score for sentence 504 is: 1.6404
# Detection Score for sentence 505 is: 1.0800
# Detection Score for sentence 506 is: 1.3853
# Detection Score for sentence 507 is: 1.2816
# Detection Score for sentence 508 is: 1.0279
# Detection Score for sentence 509 is: 1.6756
# Detection Score for sentence 510 is: 0.7883
# Detection Score for sentence 511 is: 0.5752
# Detection Score for sentence 512 is: 0.5510
# Detection Score for sentence 513 is: 1.3378
# Detection Score for sentence 514 is: 0.4665
# Detection Score for sentence 515 is: 0.8833
# Detection Score for sentence 516 is: 0.1878
# Detection Score for sentence 517 is: 1.0703
# Detection Score for sentence 518 is: 0.7275
# Detection Score for sentence 519 is: 0.6598
# Detection Score for sentence 520 is: 0.8412
# Detection Score for sentence 521 is: 0.5416
# Detection Score for sentence 522 is: 0.6744
# Detection Score for sentence 523 is: 0.3841
# Detection Score for sentence 524 is: 0.4787
# Detection Score for sentence 525 is: 1.6988
# Detection Score for sentence 526 is: 0.9533
# Detection Score for sentence 527 is: 1.1786
# Detection Score for sentence 528 is: 1.0348
# Detection Score for sentence 529 is: 1.3104
# Detection Score for sentence 530 is: 1.2317
# Detection Score for sentence 531 is: 0.6346
# Detection Score for sentence 532 is: 1.5386
# Detection Score for sentence 533 is: 1.5100
# Detection Score for sentence 534 is: 0.8108
# Detection Score for sentence 535 is: 1.4729
# Detection Score for sentence 536 is: 0.6011
# Detection Score for sentence 537 is: 0.5714
# Detection Score for sentence 538 is: 0.9670
# Detection Score for sentence 539 is: 1.2072
# Detection Score for sentence 540 is: 1.5581
# Detection Score for sentence 541 is: 1.0987
# Detection Score for sentence 542 is: 0.9188
# Detection Score for sentence 543 is: 0.7352
# Detection Score for sentence 544 is: 1.3370
# Detection Score for sentence 545 is: 1.0021
# Detection Score for sentence 546 is: 0.1163
# Detection Score for sentence 547 is: 1.5452
# Detection Score for sentence 548 is: 0.4992
# Detection Score for sentence 549 is: -0.4950
# Detection Score for sentence 550 is: 0.9358
# Detection Score for sentence 551 is: 0.7264
# Detection Score for sentence 552 is: 1.8813
# Detection Score for sentence 553 is: 0.2298
# Detection Score for sentence 554 is: 1.4980
# Detection Score for sentence 555 is: 1.7961
# Detection Score for sentence 556 is: 0.4636
# Detection Score for sentence 557 is: 0.7157
# Detection Score for sentence 558 is: 0.4382
# Detection Score for sentence 559 is: 0.4093
# Detection Score for sentence 560 is: 1.0485
# Detection Score for sentence 561 is: 0.8057
# Detection Score for sentence 562 is: 0.8310
# Detection Score for sentence 563 is: 0.7679
# Detection Score for sentence 564 is: 1.0524
# Detection Score for sentence 565 is: 0.6776
# Detection Score for sentence 566 is: 1.2480
# Detection Score for sentence 567 is: 0.9121
# Detection Score for sentence 568 is: 1.5287
# Detection Score for sentence 569 is: 0.0842
# Detection Score for sentence 570 is: 0.9113
# Detection Score for sentence 571 is: 1.1602
# Detection Score for sentence 572 is: 0.7475
# Detection Score for sentence 573 is: 0.3410
# Detection Score for sentence 574 is: 0.8817
# Detection Score for sentence 575 is: 1.6329
# Detection Score for sentence 576 is: 1.7843
# Detection Score for sentence 577 is: 0.8173
# Detection Score for sentence 578 is: 1.4277
# Detection Score for sentence 579 is: 0.7174
# Detection Score for sentence 580 is: 1.3649
# Detection Score for sentence 581 is: 0.7886
# Detection Score for sentence 582 is: 0.4999
# Detection Score for sentence 583 is: 0.5494
# Detection Score for sentence 584 is: 1.5085
# Detection Score for sentence 585 is: 1.0108
# Detection Score for sentence 586 is: 0.9764
# Detection Score for sentence 587 is: 0.8371
# Detection Score for sentence 588 is: 0.2444
# Detection Score for sentence 589 is: 1.1410
# Detection Score for sentence 590 is: 0.7549
# Detection Score for sentence 591 is: 1.3680
# Detection Score for sentence 592 is: 1.4278
# Detection Score for sentence 593 is: 0.8820
# Detection Score for sentence 594 is: 0.9469
# Detection Score for sentence 595 is: 0.7041
# Detection Score for sentence 596 is: 1.7086
# Detection Score for sentence 597 is: 0.5157
# Detection Score for sentence 598 is: 0.7793
# Detection Score for sentence 599 is: 1.2470
# Detection Score for sentence 600 is: 0.9232
# Detection Score for sentence 601 is: 0.5998
# Detection Score for sentence 602 is: 0.8602
# Detection Score for sentence 603 is: 0.9811
# Detection Score for sentence 604 is: 1.5547
# Detection Score for sentence 605 is: 0.9204
# Detection Score for sentence 606 is: 0.8077
# Detection Score for sentence 607 is: 1.2246
# Detection Score for sentence 608 is: 0.4816
# Detection Score for sentence 609 is: 1.2284
# Detection Score for sentence 610 is: 0.9073
# Detection Score for sentence 611 is: 1.2768
# Detection Score for sentence 612 is: 1.4931
# Detection Score for sentence 613 is: 0.7492
# Detection Score for sentence 614 is: 1.3553
# Detection Score for sentence 615 is: 0.5808
# Detection Score for sentence 616 is: 1.5793
# Detection Score for sentence 617 is: 0.5988
# Detection Score for sentence 618 is: 1.5265
# Detection Score for sentence 619 is: 1.4791
# Detection Score for sentence 620 is: 1.3114
# Detection Score for sentence 621 is: 1.2937
# Detection Score for sentence 622 is: 0.6709
# Detection Score for sentence 623 is: 1.1808
# Detection Score for sentence 624 is: 0.7888
# Detection Score for sentence 625 is: 1.4649
# Detection Score for sentence 626 is: 0.5819
# Detection Score for sentence 627 is: 0.9203
# Detection Score for sentence 628 is: 0.7857
# Detection Score for sentence 629 is: 0.6616
# Detection Score for sentence 630 is: 0.1825
# Detection Score for sentence 631 is: 0.7334
# Detection Score for sentence 632 is: 0.7118
# Detection Score for sentence 633 is: 1.3053
# Detection Score for sentence 634 is: 1.4268
# Detection Score for sentence 635 is: 1.0292
# Detection Score for sentence 636 is: 0.9682
# Detection Score for sentence 637 is: 0.1461
# Detection Score for sentence 638 is: 0.8644
# Detection Score for sentence 639 is: 1.5864
# Detection Score for sentence 640 is: 0.9342
# Detection Score for sentence 641 is: 1.4581
# Detection Score for sentence 642 is: 1.0060
# Detection Score for sentence 643 is: 1.1409
# Detection Score for sentence 644 is: 0.6000
# Detection Score for sentence 645 is: 0.6949
# Detection Score for sentence 646 is: 0.5252
# Detection Score for sentence 647 is: 0.5881
# Detection Score for sentence 648 is: 0.1538
# Detection Score for sentence 649 is: 1.4248
# Detection Score for sentence 650 is: 0.8248
# Detection Score for sentence 651 is: 0.7481
# Detection Score for sentence 652 is: 0.7204
# Detection Score for sentence 653 is: 0.8216
# Detection Score for sentence 654 is: 1.2282
# Detection Score for sentence 655 is: 0.7934
# Detection Score for sentence 656 is: 0.6373
# Detection Score for sentence 657 is: 0.9215
# Detection Score for sentence 658 is: 0.9899
# Detection Score for sentence 659 is: 0.7408
# Detection Score for sentence 660 is: 1.5616
# Detection Score for sentence 661 is: 0.2781
# Detection Score for sentence 662 is: 1.6818
# Detection Score for sentence 663 is: 1.1348
# Detection Score for sentence 664 is: 1.2532
# Detection Score for sentence 665 is: -0.0470
# Detection Score for sentence 666 is: 0.7115
# Detection Score for sentence 667 is: 1.6677
# Detection Score for sentence 668 is: 1.5151
# Detection Score for sentence 669 is: 1.4826
# Detection Score for sentence 670 is: 1.5931
# Detection Score for sentence 671 is: 0.7411
# Detection Score for sentence 672 is: 0.3262
# Detection Score for sentence 673 is: 1.0686
# Detection Score for sentence 674 is: 1.2192
# Detection Score for sentence 675 is: 0.1714
# Detection Score for sentence 676 is: 0.5472
# Detection Score for sentence 677 is: 1.5434
# Detection Score for sentence 678 is: 1.6527
# Detection Score for sentence 679 is: 1.3891
# Detection Score for sentence 680 is: 0.1746
# Detection Score for sentence 681 is: 1.0154
# Detection Score for sentence 682 is: 1.2949
# Detection Score for sentence 683 is: 1.1161
# Detection Score for sentence 684 is: 0.4148
# Detection Score for sentence 685 is: 1.3278
# Detection Score for sentence 686 is: 0.5561
# Detection Score for sentence 687 is: 0.6618
# Detection Score for sentence 688 is: 1.5121
# Detection Score for sentence 689 is: 0.5503
# Detection Score for sentence 690 is: 0.2208
# Detection Score for sentence 691 is: 1.6524
# Detection Score for sentence 692 is: 0.8496
# Detection Score for sentence 693 is: 1.5982
# Detection Score for sentence 694 is: 1.0542
# Detection Score for sentence 695 is: 1.3454
# Detection Score for sentence 696 is: 0.9671
# Detection Score for sentence 697 is: 0.8067
# Detection Score for sentence 698 is: 0.7149
# Detection Score for sentence 699 is: 0.9919
# Detection Score for sentence 700 is: 1.2342
# Detection Score for sentence 701 is: 1.6278
# Detection Score for sentence 702 is: 0.8951
# Detection Score for sentence 703 is: 0.5635
# Detection Score for sentence 704 is: 1.3018
# Detection Score for sentence 705 is: 0.2830
# Detection Score for sentence 706 is: 0.6669
# Detection Score for sentence 707 is: 0.4176
# Detection Score for sentence 708 is: 0.7921
# Detection Score for sentence 709 is: 0.4153
# Detection Score for sentence 710 is: 0.6223
# Detection Score for sentence 711 is: 0.5888
# Detection Score for sentence 712 is: 1.3439
# Detection Score for sentence 713 is: 0.7331
# Detection Score for sentence 714 is: 1.1660
# Detection Score for sentence 715 is: 0.6083
# Detection Score for sentence 716 is: 1.5285
# Detection Score for sentence 717 is: 0.8510
# Detection Score for sentence 718 is: 1.2636
# Detection Score for sentence 719 is: 0.5643
# Detection Score for sentence 720 is: 0.6876
# Detection Score for sentence 721 is: 0.9827
# Detection Score for sentence 722 is: 0.2526
# Detection Score for sentence 723 is: 1.2171
# Detection Score for sentence 724 is: 0.5676
# Detection Score for sentence 725 is: 0.9276
# Detection Score for sentence 726 is: 0.9199
# Detection Score for sentence 727 is: 0.9122
# Detection Score for sentence 728 is: 1.4919
# Detection Score for sentence 729 is: 1.0277
# Detection Score for sentence 730 is: 0.0595
# Detection Score for sentence 731 is: 0.6781
# Detection Score for sentence 732 is: 1.2993
# Detection Score for sentence 733 is: 1.5355
# Detection Score for sentence 734 is: 1.1847
# Detection Score for sentence 735 is: 1.3189
# Detection Score for sentence 736 is: 1.3584
# Detection Score for sentence 737 is: 1.1981
# Detection Score for sentence 738 is: 0.8791
# Detection Score for sentence 739 is: 0.1317
# Detection Score for sentence 740 is: 0.6827
# Detection Score for sentence 741 is: 1.0313
# Detection Score for sentence 742 is: 0.9203
# Detection Score for sentence 743 is: 1.4636
# Detection Score for sentence 744 is: 1.0820
# Detection Score for sentence 745 is: 0.6639
# Detection Score for sentence 746 is: 1.0782
# Detection Score for sentence 747 is: 0.6746
# Detection Score for sentence 748 is: 0.6261
# Detection Score for sentence 749 is: 1.7980
# Detection Score for sentence 750 is: 0.4788
# Detection Score for sentence 751 is: 0.7451
# Detection Score for sentence 752 is: 0.2533
# Detection Score for sentence 753 is: 0.8902
# Detection Score for sentence 754 is: 1.1463
# Detection Score for sentence 755 is: 1.5109
# Detection Score for sentence 756 is: 1.2385
# Detection Score for sentence 757 is: 1.6125
# Detection Score for sentence 758 is: 1.1037
# Detection Score for sentence 759 is: 1.1656
# Detection Score for sentence 760 is: 0.8201
# Detection Score for sentence 761 is: 0.6670
# Detection Score for sentence 762 is: 0.4765
# Detection Score for sentence 763 is: 1.3942
# Detection Score for sentence 764 is: 0.7245
# Detection Score for sentence 765 is: 1.2825
# Detection Score for sentence 766 is: 1.1664
# Detection Score for sentence 767 is: 0.3922
# Detection Score for sentence 768 is: 0.5022
# Detection Score for sentence 769 is: 0.7949
# Detection Score for sentence 770 is: 1.0832
# Detection Score for sentence 771 is: 0.3612
# Detection Score for sentence 772 is: 1.0463
# Detection Score for sentence 773 is: 1.0928
# Detection Score for sentence 774 is: -0.5261
# Detection Score for sentence 775 is: 0.9660
# Detection Score for sentence 776 is: 0.5399
# Detection Score for sentence 777 is: 1.0332
# Detection Score for sentence 778 is: 1.3055
# Detection Score for sentence 779 is: 1.3982
# Detection Score for sentence 780 is: 1.5360
# Detection Score for sentence 781 is: 1.0529
# Detection Score for sentence 782 is: 0.6901
# Detection Score for sentence 783 is: 1.4018
# Detection Score for sentence 784 is: 0.7224
# Detection Score for sentence 785 is: 1.0807
# Detection Score for sentence 786 is: 0.7115
# Detection Score for sentence 787 is: 1.0277
# Detection Score for sentence 788 is: 1.4958
# Detection Score for sentence 789 is: 1.3486
# Detection Score for sentence 790 is: 0.2438
# Detection Score for sentence 791 is: 0.8235
# Detection Score for sentence 792 is: 1.0233
# Detection Score for sentence 793 is: 0.7367
# Detection Score for sentence 794 is: 1.5783
# Detection Score for sentence 795 is: 1.3827
# Detection Score for sentence 796 is: 0.3541
# Detection Score for sentence 797 is: 1.2402
# Detection Score for sentence 798 is: 1.3789
# Detection Score for sentence 799 is: 0.9561
# Detection Score for sentence 800 is: 1.2639
# Detection Score for sentence 801 is: 0.7941
# Detection Score for sentence 802 is: 1.0610
# Detection Score for sentence 803 is: 1.1497
# Detection Score for sentence 804 is: 1.5544
# Detection Score for sentence 805 is: 1.2536
# Detection Score for sentence 806 is: 1.2907
# Detection Score for sentence 807 is: 0.8660
# Detection Score for sentence 808 is: 1.1402
# Detection Score for sentence 809 is: 0.7922
# Detection Score for sentence 810 is: 1.6391
# Detection Score for sentence 811 is: 1.4702
# Detection Score for sentence 812 is: 0.9526
# Detection Score for sentence 813 is: 0.6949
# Detection Score for sentence 814 is: 1.3744
# Detection Score for sentence 815 is: 0.5349
# Detection Score for sentence 816 is: 0.4179
# Detection Score for sentence 817 is: 0.9287
# Detection Score for sentence 818 is: 1.6189
# Detection Score for sentence 819 is: -1.4863
# Detection Score for sentence 820 is: 0.5985
# Detection Score for sentence 821 is: 1.1652
# Detection Score for sentence 822 is: 1.4636
# Detection Score for sentence 823 is: 0.9897
# Detection Score for sentence 824 is: 0.4273
# Detection Score for sentence 825 is: 0.3906
# Detection Score for sentence 826 is: 1.7743
# Detection Score for sentence 827 is: 0.9988
# Detection Score for sentence 828 is: 0.8363
# Detection Score for sentence 829 is: 0.8162
# Detection Score for sentence 830 is: 1.1005
# Detection Score for sentence 831 is: 0.8474
# Detection Score for sentence 832 is: 1.2059
# Detection Score for sentence 833 is: 0.5470
# Detection Score for sentence 834 is: 1.4669
# Detection Score for sentence 835 is: 0.8393
# Detection Score for sentence 836 is: 0.9048
# Detection Score for sentence 837 is: 0.2737
# Detection Score for sentence 838 is: 1.2094
# Detection Score for sentence 839 is: 1.3235
# Detection Score for sentence 840 is: 0.5691
# Detection Score for sentence 841 is: 0.8616
# Detection Score for sentence 842 is: 0.8881
# Detection Score for sentence 843 is: 1.4370
# Detection Score for sentence 844 is: -0.0500
# Detection Score for sentence 845 is: 0.8877
# Detection Score for sentence 846 is: 1.4218
# Detection Score for sentence 847 is: 0.9342
# Detection Score for sentence 848 is: 1.1960
# Detection Score for sentence 849 is: 0.6873
# Detection Score for sentence 850 is: 1.3874
# Detection Score for sentence 851 is: 0.6207
# Detection Score for sentence 852 is: 0.5514
# Detection Score for sentence 853 is: 0.6357
# Detection Score for sentence 854 is: 0.9166
# Detection Score for sentence 855 is: 1.4039
# Detection Score for sentence 856 is: 0.4904
# Detection Score for sentence 857 is: 1.0518
# Detection Score for sentence 858 is: 0.3281
# Detection Score for sentence 859 is: 1.6618
# Detection Score for sentence 860 is: 0.7801
# Detection Score for sentence 861 is: 0.3845
# Detection Score for sentence 862 is: 1.4985
# Detection Score for sentence 863 is: 1.1297
# Detection Score for sentence 864 is: 1.1887
# Detection Score for sentence 865 is: 0.9765
# Detection Score for sentence 866 is: 0.9056
# Detection Score for sentence 867 is: 1.0235
# Detection Score for sentence 868 is: 0.6978
# Detection Score for sentence 869 is: 0.7815
# Detection Score for sentence 870 is: 0.8861
# Detection Score for sentence 871 is: 0.6903
# Detection Score for sentence 872 is: 1.6684
# Detection Score for sentence 873 is: 0.7269
# Detection Score for sentence 874 is: 0.4546
# Detection Score for sentence 875 is: 1.6524
# Detection Score for sentence 876 is: 0.8941
# Detection Score for sentence 877 is: 0.9757
# Detection Score for sentence 878 is: 0.8413
# Detection Score for sentence 879 is: 1.0318
# Detection Score for sentence 880 is: 0.6340
# Detection Score for sentence 881 is: 0.6560
# Detection Score for sentence 882 is: 1.4882
# Detection Score for sentence 883 is: 0.8123
# Detection Score for sentence 884 is: 1.4178
# Detection Score for sentence 885 is: 0.9674
# Detection Score for sentence 886 is: 0.8140
# Detection Score for sentence 887 is: 1.0621
# Detection Score for sentence 888 is: 0.5287
# Detection Score for sentence 889 is: 1.3965
# Detection Score for sentence 890 is: 1.4024
# Detection Score for sentence 891 is: 0.9160
# Detection Score for sentence 892 is: 1.5098
# Detection Score for sentence 893 is: 0.7066
# Detection Score for sentence 894 is: 0.8575
# Detection Score for sentence 895 is: 0.3948
# Detection Score for sentence 896 is: 0.5634
# Detection Score for sentence 897 is: 1.2272
# Detection Score for sentence 898 is: 1.5637
# Detection Score for sentence 899 is: -0.0098
# Detection Score for sentence 900 is: 0.8809
# Detection Score for sentence 901 is: 1.2322
# Detection Score for sentence 902 is: 0.6223
# Detection Score for sentence 903 is: 1.2251
# Detection Score for sentence 904 is: 0.1630
# Detection Score for sentence 905 is: 0.8922
# Detection Score for sentence 906 is: 1.5885
# Detection Score for sentence 907 is: 0.4691
# Detection Score for sentence 908 is: 1.0832
# Detection Score for sentence 909 is: -0.5043
# Detection Score for sentence 910 is: -1.2119
# Detection Score for sentence 911 is: 1.0183
# Detection Score for sentence 912 is: 1.0185
# Detection Score for sentence 913 is: 1.7256
# Detection Score for sentence 914 is: 0.6104
# Detection Score for sentence 915 is: 0.7203
# Detection Score for sentence 916 is: 1.2786
# Detection Score for sentence 917 is: 0.6641
# Detection Score for sentence 918 is: 0.5633
# Detection Score for sentence 919 is: 0.6066
# Detection Score for sentence 920 is: 0.9895
# Detection Score for sentence 921 is: 0.9398
# Detection Score for sentence 922 is: -0.4628
# Detection Score for sentence 923 is: 0.5511
# Detection Score for sentence 924 is: 0.7429
# Detection Score for sentence 925 is: 0.9958
# Detection Score for sentence 926 is: 0.8615
# Detection Score for sentence 927 is: 0.8692
# Detection Score for sentence 928 is: 1.4902
# Detection Score for sentence 929 is: 1.4908
# Detection Score for sentence 930 is: 1.5647
# Detection Score for sentence 931 is: 0.7927
# Detection Score for sentence 932 is: 0.6283
# Detection Score for sentence 933 is: 1.5310
# Detection Score for sentence 934 is: 0.5393
# Detection Score for sentence 935 is: 0.6903
# Detection Score for sentence 936 is: 0.6010
# Detection Score for sentence 937 is: 0.7661
# Detection Score for sentence 938 is: 1.0903
# Detection Score for sentence 939 is: 1.5010
# Detection Score for sentence 940 is: 1.4333
# Detection Score for sentence 941 is: 1.1152
# Detection Score for sentence 942 is: 1.2469
# Detection Score for sentence 943 is: 1.0336
# Detection Score for sentence 944 is: 0.5688
# Detection Score for sentence 945 is: 0.5529
# Detection Score for sentence 946 is: 1.4791
# Detection Score for sentence 947 is: 1.3564
# Detection Score for sentence 948 is: 0.5499
# Detection Score for sentence 949 is: 0.6098
# Detection Score for sentence 950 is: 0.2709
# Detection Score for sentence 951 is: 1.3204
# Detection Score for sentence 952 is: 0.9555
# Detection Score for sentence 953 is: 1.3251
# Detection Score for sentence 954 is: 0.5338
# Detection Score for sentence 955 is: 0.2251
# Detection Score for sentence 956 is: 1.4462
# Detection Score for sentence 957 is: 1.3146
# Detection Score for sentence 958 is: 0.6150
# Detection Score for sentence 959 is: 1.5899
# Detection Score for sentence 960 is: 0.7273
# Detection Score for sentence 961 is: 0.5767
# Detection Score for sentence 962 is: 0.9296
# Detection Score for sentence 963 is: 0.3210
# Detection Score for sentence 964 is: 1.5893
# Detection Score for sentence 965 is: 1.5204
# Detection Score for sentence 966 is: 1.0750
# Detection Score for sentence 967 is: 1.2461
# Detection Score for sentence 968 is: 0.9872
# Detection Score for sentence 969 is: 1.4078
# Detection Score for sentence 970 is: 0.8772
# Detection Score for sentence 971 is: 1.4883
# Detection Score for sentence 972 is: 0.7402
# Detection Score for sentence 973 is: 1.2514
# Detection Score for sentence 974 is: 1.2281
# Detection Score for sentence 975 is: 1.0559
# Detection Score for sentence 976 is: 1.0251
# Detection Score for sentence 977 is: 1.6573
# Detection Score for sentence 978 is: 1.4313
# Detection Score for sentence 979 is: 0.8316
# Detection Score for sentence 980 is: 0.8652
# Detection Score for sentence 981 is: 1.5714
# Detection Score for sentence 982 is: 0.9352
# Detection Score for sentence 983 is: 0.6647
# Detection Score for sentence 984 is: 1.2095
# Detection Score for sentence 985 is: 1.3485
# Detection Score for sentence 986 is: 0.6322
# Detection Score for sentence 987 is: 1.3147
# Detection Score for sentence 988 is: 1.7951
# Detection Score for sentence 989 is: 0.9889
# Detection Score for sentence 990 is: 0.4351
# Detection Score for sentence 991 is: 1.7117
# Detection Score for sentence 992 is: 1.1807
# Detection Score for sentence 993 is: 0.8206
# Detection Score for sentence 994 is: 1.2493
# Detection Score for sentence 995 is: 1.4476
# Detection Score for sentence 996 is: 1.5558
# Detection Score for sentence 997 is: 0.8871
# Detection Score for sentence 998 is: 0.8391
# Detection Score for sentence 999 is: 0.9513
# Detection Score for sentence 1000 is: 0.9503
# Detection Score for sentence 1001 is: 1.4536
# Detection Score for sentence 1002 is: 0.9732
# Detection Score for sentence 1003 is: 1.3891
# Detection Score for sentence 1004 is: 0.7016
# Detection Score for sentence 1005 is: 1.0579
# Detection Score for sentence 1006 is: 1.3100
# Detection Score for sentence 1007 is: 0.7415
# Detection Score for sentence 1008 is: 0.4023
# Detection Score for sentence 1009 is: 0.7550
# Detection Score for sentence 1010 is: 0.8630
# Detection Score for sentence 1011 is: 0.6300
# Detection Score for sentence 1012 is: 1.1909
# Detection Score for sentence 1013 is: 1.0362
# Detection Score for sentence 1014 is: 0.9190
# Detection Score for sentence 1015 is: 0.8697
# Detection Score for sentence 1016 is: 1.0571
# Detection Score for sentence 1017 is: 0.6255
# Detection Score for sentence 1018 is: 1.2206
# Detection Score for sentence 1019 is: 0.9386
# Detection Score for sentence 1020 is: 0.9268
# Detection Score for sentence 1021 is: 0.8883
# Detection Score for sentence 1022 is: 0.8928
# Detection Score for sentence 1023 is: 0.6472
# Detection Score for sentence 1024 is: 1.3908
# Detection Score for sentence 1025 is: 1.0612
# Detection Score for sentence 1026 is: 1.4203
# Detection Score for sentence 1027 is: 1.0858
# Detection Score for sentence 1028 is: 0.9797
# Detection Score for sentence 1029 is: 1.5524
# Detection Score for sentence 1030 is: 0.2806
# Detection Score for sentence 1031 is: 1.5035
# Detection Score for sentence 1032 is: 0.9731
# Detection Score for sentence 1033 is: 0.9819
# Detection Score for sentence 1034 is: 0.8811
# Detection Score for sentence 1035 is: 1.0623
# Detection Score for sentence 1036 is: 0.2848
# Detection Score for sentence 1037 is: 0.4830
# Detection Score for sentence 1038 is: 0.5839
# Detection Score for sentence 1039 is: 0.7509
# Detection Score for sentence 1040 is: 0.6853
# Detection Score for sentence 1041 is: 1.3082
# Detection Score for sentence 1042 is: 0.6127
# Detection Score for sentence 1043 is: 1.3798
# Detection Score for sentence 1044 is: 0.9516
# Detection Score for sentence 1045 is: 0.6490
# Detection Score for sentence 1046 is: 0.9820
# Detection Score for sentence 1047 is: 1.4063
# Detection Score for sentence 1048 is: 1.4791
# Detection Score for sentence 1049 is: 0.8243
# Detection Score for sentence 1050 is: 0.7611
# Detection Score for sentence 1051 is: 0.7506
# Detection Score for sentence 1052 is: 1.0302
# Detection Score for sentence 1053 is: 0.5653
# Detection Score for sentence 1054 is: 0.5538
# Detection Score for sentence 1055 is: -0.2390
# Detection Score for sentence 1056 is: 0.7434
# Detection Score for sentence 1057 is: 1.4074
# Detection Score for sentence 1058 is: 0.2708
# Detection Score for sentence 1059 is: 1.5359
# Detection Score for sentence 1060 is: 0.6009
# Detection Score for sentence 1061 is: 0.8790
# Detection Score for sentence 1062 is: 0.4080
# Detection Score for sentence 1063 is: 0.8030
# Detection Score for sentence 1064 is: 0.5411
# Detection Score for sentence 1065 is: 0.7362
# Detection Score for sentence 1066 is: 0.6087
# Detection Score for sentence 1067 is: 1.4416
# Detection Score for sentence 1068 is: 1.5458
# Detection Score for sentence 1069 is: 1.6495
# Detection Score for sentence 1070 is: 0.7209
# Detection Score for sentence 1071 is: 1.6928
# Detection Score for sentence 1072 is: 1.1235
# Detection Score for sentence 1073 is: 0.6144
# Detection Score for sentence 1074 is: 0.3487
# Detection Score for sentence 1075 is: 0.7690
# Detection Score for sentence 1076 is: 1.2388
# Detection Score for sentence 1077 is: 1.7088
# Detection Score for sentence 1078 is: 0.8577
# Detection Score for sentence 1079 is: 1.1313
# Detection Score for sentence 1080 is: 1.1479
# Detection Score for sentence 1081 is: 1.1262
# Detection Score for sentence 1082 is: 1.0246
# Detection Score for sentence 1083 is: 0.8937
# Detection Score for sentence 1084 is: 0.6323
# Detection Score for sentence 1085 is: 1.0287
# Detection Score for sentence 1086 is: 1.1651
# Detection Score for sentence 1087 is: 0.6896
# Detection Score for sentence 1088 is: 1.4246
# Detection Score for sentence 1089 is: 0.7241
# Detection Score for sentence 1090 is: 1.3051
# Detection Score for sentence 1091 is: 0.7438
# Detection Score for sentence 1092 is: 0.4954
# Detection Score for sentence 1093 is: 0.6189
# Detection Score for sentence 1094 is: 1.4729
# Detection Score for sentence 1095 is: 1.2299
# Detection Score for sentence 1096 is: 1.7118
# Detection Score for sentence 1097 is: 0.9215
# Detection Score for sentence 1098 is: 0.6718
# Detection Score for sentence 1099 is: 1.3212
# Detection Score for sentence 1100 is: 0.8411
# Detection Score for sentence 1101 is: 1.6238
# Detection Score for sentence 1102 is: 0.7626
# Detection Score for sentence 1103 is: 1.2790
# Detection Score for sentence 1104 is: 0.6235
# Detection Score for sentence 1105 is: 1.6142
# Detection Score for sentence 1106 is: 0.9833

# %%
print_gpu_memory()
# Out:
# GPU Name: Tesla P100-PCIE-16GB
# Total memory: 16269.25 MB
# Allocated memory: 495.18 MB
# Reserved memory: 504.00 MB
# Free (unreserved) memory: 8.82 MB

# %%
score_dataset = smaller_dataset.copy()
score_dataset["pred score"] = pred_scores
score_dataset.head()
# Out:
#                                                   text  generated  pred score
# 182  Limiting car usage can have several advantages...          1    1.492491
# 751  "America's love affair with it's vehicles seem...          0    0.919343
# 801  Reducing the usage of cars in today's world co...          0    0.953056
# 385  [Your Name]\n[Your Address]\n[City, State, ZIP...          1    0.772685
# 495  [Your Name]\n[Your Address]\n[City, State, ZIP...          1    1.132379

# %%
score_dataset.to_csv("score_dataset.csv", index=False)
